# %% [markdown]
# # What is it that people want to learn in Data Science ?
#
# Our Goal in this project is to scour the internet ( particularly <a href='https://datascience.stackexchange.com/' target='_blank'> Data Science Stack exchange</a> ) in search of popular Data Science questions or any fields of Data Science people want to learn.
#
# <a href='https://stackexchange.com/tour' target='_blank'>Stack Exchange </a> is world largest programming community created and run by experts and enthusiasts who are passionate about specific topic .It has dedicated sites on multitude of fields and subjects like Mathematics, Stack Overflow, Physics,Data Science etc. Stack Exchange employs a reputation award system for its questions and answers. Each post — each question/answer — is a post that is subject to upvotes and downvotes.
#
# We explore one of its dedicated site Data Science Stack Exchange <a href='https://datascience.stackexchange.com/' target='_blank'>(DSSE) </a> and find that tagging system used by System Exchange will be very useful in categorizng content.
#
# ## Getting the data - Stack Exchange Data Explorer
# Stack Exchange provide public data base for each of its websites. To get the relevant data we run the following query to Data Science dedicated <a href='https://data.stackexchange.com/datascience/query/new' target='_blank' >data explorer </a> and downloaded the rows in ` 2022_questions.csv `.
# ```
# SELECT Id, CreationDate,
#        Score, ViewCount, Tags,
#        AnswerCount, FavoriteCount
# FROM posts
# WHERE PostTypeId = 1 AND YEAR(CreationDate) = 2022;
# ```

# %% [markdown]
# `Id` : An Identification number for the post
#
# `CreationDate` : The date and time of creation of the post
#
# `Score` : The Post's score
#
# `ViewCount` : How many times the post was viewed
#
# `Tags` : What tags were used
#
# `AnswerCount` : How many answers the question got
#
# `FavouriteCount` : How many times the question was favoured
#
# PostTypeId 1 is for Question

# %% [markdown]
# ### Exploring the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read csv file and parsing CreationDate as Datetime Object
questions = pd.read_csv('dataset/2022_questions.csv', parse_dates =['CreationDate'])
display(questions.head())
print(questions.info())
# Out:
#        Id        CreationDate  Score  ViewCount  \
# 0  106600 2022-01-01 00:20:53      2       1097
# 1  106602 2022-01-01 03:32:55      3        123
# 2  106603 2022-01-01 06:18:52      0         31
# 3  106607 2022-01-01 15:07:25      1         21
# 4  106609 2022-01-01 15:40:23      0         27
#
#                                                 Tags  AnswerCount  \
# 0            <python><keras><tensorflow><regression>            1
# 1         <deep-learning><word-embeddings><deepmind>            1
# 2                     <logistic-regression><sigmoid>            1
# 3  <machine-learning><python><pandas><statistics>...            0
# 4                    <nlp><data-science-model><bert>            0
#
#    FavoriteCount
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5627 entries, 0 to 5626
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             5627 non-null   int64
#  1   CreationDate   5627 non-null   datetime64[ns]
#  2   Score          5627 non-null   int64
#  3   ViewCount      5627 non-null   int64
#  4   Tags           5627 non-null   object
#  5   AnswerCount    5627 non-null   int64
#  6   FavoriteCount  20 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(1)
# memory usage: 307.9+ KB
# None

# %% [markdown]
# Observations :
#  - Tranform values in `Tags` to look more like list [ machine-learning , regression]
#  - `FavoriteCount` has missing values.

# %% [markdown]
# ## Data Cleaning

# %%
# Fill null values with 0
questions.fillna(value = {'FavoriteCount':0},inplace = True)
# change to int dtype
questions['FavoriteCount'] = questions['FavoriteCount'].astype(int)
#checking
questions.dtypes
# Out:
# Id                        int64
# CreationDate     datetime64[ns]
# Score                     int64
# ViewCount                 int64
# Tags                     object
# AnswerCount               int64
# FavoriteCount             int32
# dtype: object

# %%
#clean the tag columns
questions['Tags']= questions['Tags'].str.replace('^<|>$',"").str.split('><')
questions.sample(3)
# Out:
# <ipython-input-13-b7f21418cb8e>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   questions['Tags']= questions['Tags'].str.replace('^<|>$',"").str.split('><')
#           Id        CreationDate  Score  ViewCount  \
# 827   108379 2022-02-21 09:30:16      0        137
# 4798  115897 2022-11-04 21:39:57      0         19
# 1957  110466 2022-04-28 19:26:06      0        424
#
#                                                    Tags  AnswerCount  \
# 827   [image-classification, similarity, image-recog...            0
# 4798                      [python, deep-learning, data]            0
# 1957                     [pytorch, batch-normalization]            0
#
#       FavoriteCount
# 827               0
# 4798              0
# 1957              0

# %% [markdown]
# We now focus on finding popular tags. We do this by considering two different popularity proxies - how many times each tag was used and how many times a questio with that tag was viewed.
#
# Now we limit our research to counts and views `ViewCount`.

# %% [markdown]
# ## Most used and Most Viewed

# %% [markdown]
# We begin by counting how many times each tags were used

# %%
# two empty dict for count and views
tag_count = dict()
tag_view_count = dict()

#iterate through each row of questions Dataframe
for index, row in questions.iterrows():
    #iterate through Tag Column of each row
    for tag in row['Tags']:
        if tag in tag_view_count:
            tag_count[tag] += 1
            tag_view_count[tag] += row['ViewCount']
        else:
            tag_count[tag] = 1 
            tag_view_count[tag] = row['ViewCount']

# %% [markdown]
# `most_used` : Dataframe that counts how many times each of the top 20 tags used
#
# `most_viewed` : Dataframe that counts how many times each of the top 20 tags viewed

# %%
# transform dict to Dataframe
tag_count = pd.DataFrame.from_dict(tag_count,orient = 'index')
tag_view_count = pd.DataFrame.from_dict(tag_view_count,orient ='index')
#Rename the columns
tag_count.columns =['Count']
tag_view_count.columns = ['ViewCount']
# sort these Dataframes in ascending order and take top 20 results
most_used = tag_count.sort_values('Count').tail(20)
most_viewed = tag_view_count.sort_values('ViewCount').tail(20)
display(most_used)
display(most_viewed)
# Out:
#                         Count
# pandas                    174
# statistics                174
# pytorch                   182
# data-science-model        183
# cnn                       189
# clustering                194
# dataset                   196
# machine-learning-model    204
# lstm                      221
# regression                272
# scikit-learn              306
# keras                     317
# tensorflow                339
# time-series               389
# classification            450
# neural-network            455
# nlp                       467
# deep-learning             812
# python                    934
# machine-learning         1533
#                         ViewCount
# cnn                         14781
# regression                  15002
# random-forest               16213
# clustering                  16444
# transformer                 17706
# dataframe                   18627
# lstm                        19450
# pytorch                     20705
# time-series                 30555
# machine-learning-model      33439
# pandas                      38828
# tensorflow                  41146
# scikit-learn                41401
# keras                       42381
# classification              47126
# nlp                         50778
# neural-network              50869
# deep-learning               95058
# python                     131458
# machine-learning           167653

# %%
plt.style.use('default')
# check top 20 tags for both most_viewed and most_used  side by side
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(24,10))
most_used.plot(kind='barh',ax=ax1,legend= False)
most_viewed.plot(kind='barh',ax=ax2, legend = False)

#titles and adjust fontsize
ax1.set_title('Most Used Tags',fontsize= 22,weight='bold')
ax2.set_title('Most Viewed Tags',fontsize = 22, weight='bold')
ax1.tick_params(axis='y',labelsize=20)
ax2.tick_params(axis='y',labelsize=20)

for ax_ in [ax1,ax2]:
    for pos in ['right','top','left']:
        ax_.spines[pos].set_visible(False)

#for equal spacing between axes
plt.tight_layout()

# %% [markdown]
# We see that most top tops are present in both dataframes.
#
# Lets see which tags is in `most_viewed` but not in `most_used`

# %%
set(most_viewed.index).difference(most_used.index)
# Out:
# {'dataframe', 'random-forest', 'transformer'}

# %% [markdown]
# tags in `most_used` but not in `most_viewed`

# %%
set(most_used.index).difference(most_viewed.index)
# Out:
# {'data-science-model', 'dataset', 'statistics'}

# %% [markdown]
# ## Relations between Tags

# %%
#get all the tags in list
all_tags = tag_count.index.tolist()

# %%
#create Dataframe initialize with int 0
corr_tags = pd.DataFrame(index = all_tags, columns = all_tags)
corr_tags.fillna(0,inplace= True)
corr_tags
# Out:
#                python  keras  tensorflow  regression  deep-learning  \
# python              0      0           0           0              0
# keras               0      0           0           0              0
# tensorflow          0      0           0           0              0
# regression          0      0           0           0              0
# deep-learning       0      0           0           0              0
# ...               ...    ...         ...         ...            ...
# share-point         0      0           0           0              0
# dirichlet           0      0           0           0              0
# kedro               0      0           0           0              0
# entropy             0      0           0           0              0
# image-size          0      0           0           0              0
#
#                word-embeddings  deepmind  logistic-regression  sigmoid  \
# python                       0         0                    0        0
# keras                        0         0                    0        0
# tensorflow                   0         0                    0        0
# regression                   0         0                    0        0
# deep-learning                0         0                    0        0
# ...                        ...       ...                  ...      ...
# share-point                  0         0                    0        0
# dirichlet                    0         0                    0        0
# kedro                        0         0                    0        0
# entropy                      0         0                    0        0
# image-size                   0         0                    0        0
#
#                machine-learning  ...  umap  crawling  document-term-matrix  \
# python                        0  ...     0         0                     0
# keras                         0  ...     0         0                     0
# tensorflow                    0  ...     0         0                     0
# regression                    0  ...     0         0                     0
# deep-learning                 0  ...     0         0                     0
# ...                         ...  ...   ...       ...                   ...
# share-point                   0  ...     0         0                     0
# dirichlet                     0  ...     0         0                     0
# kedro                         0  ...     0         0                     0
# entropy                       0  ...     0         0                     0
# image-size                    0  ...     0         0                     0
#
#                classificationmulti  data-source  share-point  dirichlet  \
# python                           0            0            0          0
# keras                            0            0            0          0
# tensorflow                       0            0            0          0
# regression                       0            0            0          0
# deep-learning                    0            0            0          0
# ...                            ...          ...          ...        ...
# share-point                      0            0            0          0
# dirichlet                        0            0            0          0
# kedro                            0            0            0          0
# entropy                          0            0            0          0
# image-size                       0            0            0          0
#
#                kedro  entropy  image-size
# python             0        0           0
# keras              0        0           0
# tensorflow         0        0           0
# regression         0        0           0
# deep-learning      0        0           0
# ...              ...      ...         ...
# share-point        0        0           0
# dirichlet          0        0           0
# kedro              0        0           0
# entropy            0        0           0
# image-size         0        0           0
#
# [611 rows x 611 columns]

# %%
for tags in questions['Tags']:
    corr_tags.loc[tags,tags] += 1

# %%
#reduce the size to ones related with most used tags
relations_most_used = corr_tags.copy().loc[most_used.index,most_used.index]
relations_most_used
# Out:
#                         pandas  statistics  pytorch  data-science-model  cnn  \
# pandas                     174           3        1                   4    0
# statistics                   3         174        0                  10    1
# pytorch                      1           0      182                   3   14
# data-science-model           4          10        3                 183    3
# cnn                          0           1       14                   3  189
# clustering                   2           8        4                   5    1
# dataset                     10           6        2                  11    3
# machine-learning-model       0           7        3                  21    1
# lstm                         2           1       14                   5   10
# regression                   7          18        4                  10   12
# scikit-learn                20           3        3                  14    0
# keras                        3           0        7                   6   30
# tensorflow                   1           0       14                   6   33
# time-series                  8          11       10                  10    8
# classification               4          14        3                  11   11
# neural-network               0           4       19                   5   19
# nlp                          2           2       21                   7    4
# deep-learning                3          11       48                  19   62
# python                      92          14       38                  39   25
# machine-learning            20          52       32                  83   36
#
#                         clustering  dataset  machine-learning-model  lstm  \
# pandas                           2       10                       0     2
# statistics                       8        6                       7     1
# pytorch                          4        2                       3    14
# data-science-model               5       11                      21     5
# cnn                              1        3                       1    10
# clustering                     194        4                       5     0
# dataset                          4      196                       7     3
# machine-learning-model           5        7                     204     1
# lstm                             0        3                       1   221
# regression                       5        7                       8    10
# scikit-learn                     9        5                      15     3
# keras                            0        6                       9    46
# tensorflow                       0        6                       8    33
# time-series                     14        6                       7    75
# classification                  13       12                      27     9
# neural-network                   0        8                      19    39
# nlp                             17       15                       4    19
# deep-learning                    7       15                      32    50
# python                          34       31                      25    33
# machine-learning                51       52                      90    48
#
#                         regression  scikit-learn  keras  tensorflow  \
# pandas                           7            20      3           1
# statistics                      18             3      0           0
# pytorch                          4             3      7          14
# data-science-model              10            14      6           6
# cnn                             12             0     30          33
# clustering                       5             9      0           0
# dataset                          7             5      6           6
# machine-learning-model           8            15      9           8
# lstm                            10             3     46          33
# regression                     272            21     10           4
# scikit-learn                    21           306      7           8
# keras                           10             7    317         147
# tensorflow                       4             8    147         339
# time-series                     21             6     17          11
# classification                  24            33     11           7
# neural-network                  24             6     56          45
# nlp                              0             8     14          13
# deep-learning                   25            10     83         104
# python                          25           120     88          93
# machine-learning                75           103     69          68
#
#                         time-series  classification  neural-network  nlp  \
# pandas                            8               4               0    2
# statistics                       11              14               4    2
# pytorch                          10               3              19   21
# data-science-model               10              11               5    7
# cnn                               8              11              19    4
# clustering                       14              13               0   17
# dataset                           6              12               8   15
# machine-learning-model            7              27              19    4
# lstm                             75               9              39   19
# regression                       21              24              24    0
# scikit-learn                      6              33               6    8
# keras                            17              11              56   14
# tensorflow                       11               7              45   13
# time-series                     389              29              21    1
# classification                   29             450              37   24
# neural-network                   21              37             455   22
# nlp                               1              24              22  467
# deep-learning                    42              57             172   93
# python                           69              60              46   62
# machine-learning                 80             172             160  130
#
#                         deep-learning  python  machine-learning
# pandas                              3      92                20
# statistics                         11      14                52
# pytorch                            48      38                32
# data-science-model                 19      39                83
# cnn                                62      25                36
# clustering                          7      34                51
# dataset                            15      31                52
# machine-learning-model             32      25                90
# lstm                               50      33                48
# regression                         25      25                75
# scikit-learn                       10     120               103
# keras                              83      88                69
# tensorflow                        104      93                68
# time-series                        42      69                80
# classification                     57      60               172
# neural-network                    172      46               160
# nlp                                93      62               130
# deep-learning                     812      99               310
# python                             99     934               251
# machine-learning                  310     251              1533

# %%
#diagonally placed values are high where same tag is on x and y.
#replace those values so colors will not be too skewed
for i in range(relations_most_used.shape[0]):
    relations_most_used.iloc[i,i] = np.nan

# %%
# create a numpy array of zeros matching the dimensions of the top_10 df
mask = np.zeros_like(relations_most_used)
# use triu_indicies to create the indices for the upper-triangle of an the array.
mask[np.triu_indices_from(mask)] = True

fig,ax = plt.subplots(figsize=(8,5))
sns.heatmap(relations_most_used,cmap='Greens', ax=ax,mask=mask)
ax.set_title('               Pairing between Most Used Tags               ',y=1.05,size= 12,backgroundcolor='green', color='white',weight='bold')
# Out:
# Text(0.5, 1.05, '               Pairing between Most Used Tags               ')

# %% [markdown]
# Observations
# - Looking at bottom right corner,Most used tags seems to have strong relations
# - Most of python libraries schikit-learn , keras, tensorflow are for Machine Learning
# - Most of tags are directing to one new area of machine learning : **Deep Learning**

# %% [markdown]
# ## Is Deep Learning just a fad?
#
# We further track the interest in deep learning across time.
#
# We run the following query to Stack Exchange Data Explorer and save results to `all_questions.csv`
#
# >```
# SELECT Id,
#        CreationDate,
#        Tags
#   FROM Posts
#  WHERE PostTypeId = 1;
# ```

# %%
#read csv file
all_questions= pd.read_csv('dataset/all_questions.csv', parse_dates=['CreationDate'])
#check for non null values and dtypes
all_questions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35417 entries, 0 to 35416
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            35417 non-null  int64
#  1   CreationDate  35417 non-null  datetime64[ns]
#  2   Tags          35417 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 830.2+ KB

# %%
#Transform Tags column in similar manner as above.
all_questions['Tags'] = all_questions['Tags'].str.replace('^<|>$','').str.split('><')
# Out:
# <ipython-input-26-2cd186882cd6>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   all_questions['Tags'] = all_questions['Tags'].str.replace('^<|>$','').str.split('><')

# %% [markdown]
# We list the tags that are related to deep learning questions. These tags are obtained at the tags in `most_used` and search for Tag Synonyms

# %%
deep_learning_list = ['python','classification','rnn','cnn','keras','tensorflow','scikit-learn','lstm','neural-network','deep-learning',
                      'image-recongnition','nlp','machine-learning','sklearn','scikit','deep-betwork','nn','natural-language-process','ml']

#function assigns 1 if tag related to deep learning is present
def class_deep_learning(tags):
    for tag in tags:
        if tag in deep_learning_list:
            return 1
    return 0
all_questions['DeepLearning'] = all_questions['Tags'].apply(class_deep_learning)
all_questions.sample(5)
# Out:
#            Id        CreationDate  \
# 34435  116710 2022-12-03 22:01:01
# 765     86146 2020-12-01 00:46:00
# 23242   21984 2017-08-05 14:40:09
# 8529    36524 2018-08-06 11:00:30
# 24560  109234 2022-03-21 13:10:40
#
#                                                     Tags  DeepLearning
# 34435    [deep-learning, anomaly-detection, autoencoder]             1
# 765    [class-imbalance, multiclass-classification, a...             0
# 23242                        [r, dataset, anonymization]             0
# 8529                               [clustering, scoring]             0
# 24560  [machine-learning, reinforcement-learning, pol...             1

# %%
#filter out any rows where Year is 2023
all_q_2022 = all_questions.copy()[all_questions['CreationDate'].dt.year < 2023]

# %%
all_q_2022['DeepLearning'].value_counts()
# Out:
# 1    24689
# 0    10624
# Name: DeepLearning, dtype: int64

# %% [markdown]
# From 2014-2022, 70% of question is related with Deep Learning or Machine Learning.

# %% [markdown]
# We decide to group data by quarter and
#
# - Count how many deep learning questions are asked
# - Count total amount of questions
# - How many deep learning questions there are relative to the total amount of questions
#
# We now define a column that identifies Quarter.

# %%
def quarter(datetime):
    year = str(datetime.year)[-2:]
    month = str(((datetime.month - 1)//3) + 1)
    return '{}Q{}'.format(year,month)
all_q_2022['Quarter'] = all_q_2022['CreationDate'].apply(quarter)
all_q_2022.sample(3)
# Out:
#           Id        CreationDate                                         Tags  \
# 3390   88177 2021-01-19 07:53:36  [machine-learning, python, tensorflow, nlp]
# 17625  74431 2020-05-19 01:53:46                                       [k-nn]
# 25565  49123 2019-04-11 13:01:27                  [python, pandas, dataframe]
#
#        DeepLearning Quarter
# 3390              1    21Q1
# 17625             0    20Q2
# 25565             1    19Q2

# %%
quarterly = all_q_2022.groupby('Quarter').agg({'DeepLearning':['sum','size']})
quarterly.columns=['DeepLearningQuestions','TotalQuestions']
quarterly.reset_index(inplace = True)
quarterly['DeepLearningRate'] = quarterly['DeepLearningQuestions']/quarterly['TotalQuestions']
quarterly.sample(3)
# Out:
#    Quarter  DeepLearningQuestions  TotalQuestions  DeepLearningRate
# 18    18Q4                    934            1265          0.738340
# 33    22Q3                    837            1301          0.643351
# 1     14Q3                    100             188          0.531915

# %%
plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(20,12),sharey= False)

ax.plot(quarterly['Quarter'], quarterly['DeepLearningRate'],color='#b51275',linestyle='--',marker='o',label='Deep Learning Rate')
ax2 = ax.twinx()
ax2.bar(quarterly['Quarter'], quarterly['TotalQuestions'],color='blue',alpha=0.4 ,label='Total Questions')

ax.text(-2,0.796,"                                     Interest in Deep Learning                                           ",
        size= 26,backgroundcolor='grey',weight='bold',color='white')
# set xlabels , remove ticks & labels 
ax.set_xlabel('Time period (Quarterly)',size=16)
ax2.yaxis.set_visible(False)

#remove left,right,top spine
ax.spines['left'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_position(('outward', 10))
ax.spines['bottom'].set_position(('outward', 10))


#rotate x tick labels
for tick in ax.get_xticklabels():
    tick.set_rotation(45)
    
for index,t in quarterly['TotalQuestions'].iteritems():
    ax2.text(index,t,str(t),ha='center', va='bottom')
    
#handling legends
handle1, label1 = ax.get_legend_handles_labels()
handle2, label2 = ax2.get_legend_handles_labels()
ax.legend(handles = handle1+handle2,labels = label1+ label2, loc="upper left",fontsize=18)

plt.savefig("interest.png")

# %% [markdown]
# #### Conclusion
#
# It seems that Deep Learning question was high growth trend till 2018, then the growth plateau. Since 2021 there seems no. of questions posted on DSSE declined and so it is reflected on Deep Learning Rate too. We see that still > 60% of questions is related to Deep Learning or Machine Learning.So we can conclude that Deep Learning or Machine Learning is astill a popular field.
#
# It would be interesting to further explore on why there is decline in people engagement and Does PostTypeId (2) for Answering display the same trend as PostTypeId(1)?
